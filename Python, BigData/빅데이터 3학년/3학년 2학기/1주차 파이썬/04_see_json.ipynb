# %%
import json

# %%
path = '/content/drive/MyDrive/aa_Python 프로그래밍 I_II/공공기관_감성분석/data/SentiWord_info.json'

# %%
with open(path, 'r') as f:
    json_data = json.load(f)

print(json.dumps(json_data) )
# Out:
# [{"word": "(-;", "word_root": "(", "polarity": "1"}, {"word": "(;_;)", "word_root": "(;_;)", "polarity": "-1"}, {"word": "(^^)", "word_root": "(^^)", "polarity": "1"}, {"word": "(^-^)", "word_root": "(^-^)", "polarity": "1"}, {"word": "(^^*", "word_root": "(", "polarity": "1"}, {"word": "(^_^)", "word_root": "(^_^)", "polarity": "1"}, {"word": "(^_^;", "word_root": "(", "polarity": "-1"}, {"word": "(^o^)", "word_root": "(^o^)", "polarity": "1"}, {"word": "(-_-)", "word_root": "(-_-)", "polarity": "-1"}, {"word": "(T_T)", "word_root": "(T_T)", "polarity": "-1"}, {"word": "(\u3161\u3161)", "word_root": "(", "polarity": "-1"}, {"word": ")-:", "word_root": ")", "polarity": "-1"}, {"word": "*^^*", "word_root": "*", "polarity": "1"}, {"word": "/^o^\\", "word_root": "/", "polarity": "1"}, {"word": ":(", "word_root": ":", "polarity": "1"}, {"word": ":'-(", "word_root": ":", "polarity": "1"}, {"word": ":-(", "word_root": ":", "polarity": "1"}, {"word": ":)", "word_root": ":", "polarity": "-1"
# ...

# %%
json_data[:5]
# Out:
# [{'word': '(-;', 'word_root': '(', 'polarity': '1'},
#  {'word': '(;_;)', 'word_root': '(;_;)', 'polarity': '-1'},
#  {'word': '(^^)', 'word_root': '(^^)', 'polarity': '1'},
#  {'word': '(^-^)', 'word_root': '(^-^)', 'polarity': '1'},
#  {'word': '(^^*', 'word_root': '(', 'polarity': '1'}]

# %%
import pandas as pd
pd.DataFrame(json_data).sample(20)
# Out:
#              word word_root polarity
# 11098    잘못을 뉘우치고    잘못 뉘우치        1
# 9918           우는         울       -1
# 11365  정답게 이야기하거나     정 이야기        2
# 12406   쭈그러져 작아지다  쭈그러지 작아지       -1
# 2107         꼭 맞다      꼭 맞닿        1
# 9581       영양이 적고      영양 적       -1
# 11168          재난        재난       -2
# 11788    좋아서 탐스러운       좋 탐        2
# 12907          쾌조        쾌조        1
# 4034      매우 간지럽고     맵 간지럽       -2
# 4000         매끄러운       매끄럽        1
# 11373     정답고 귀엽게      정 귀엽        2
# 3814       만족스럽거나        만족        2
# 8685      알아듣지 못할    알아듣 못하       -1
# 8551           악성        악성       -2
# 8835         야무지게       야무지        2
# 11877        죄가 될       죄 되       -2
# 11823       좋은 말글       좋 말        2
# 14566        희미하다        희미       -1
# 583      거칠게 행동하다     거치 행동       -2

# %%
df = pd.DataFrame(json_data)
df.sort_values('polarity').head(10)
# Out:
#              word word_root polarity
# 14853      알쏭달쏭하다      알쏭달쏭       -1
# 11294       전부 게워     전부 게우       -1
# 6354   비정상적으로 잇따라   비정상 잇따르       -1
# 11297         전염병       전염병       -1
# 6355          비정한        비정       -1
# 6356      비정한 기세나     비정 기세       -1
# 11300     전혀 모르거나     전혀 모르       -1
# 11301       전혀 없는      전혀 없       -1
# 3712     마음이 무겁거나     마음 무겁       -1
# 3704   마음이 놓이지 않아   마음 놓이 않       -1

# %%
df.sort_values('polarity', ascending=False).head(10)
# Out:
#           word word_root polarity
# 2774      능숙하게        능숙        2
# 1763    기분이 좋은      기분 좋        2
# 13005     탐스러운         탐        2
# 5243      반드럽게       반드럽        2
# 5242   반드러운 모양    반드럽 모양        2
# 5241      반드러운       반드럽        2
# 5237       반기다        반기        2
# 5236       반갑다        반갑        2
# 5235     반가운 비      반갑 비        2
# 1752      기미하다        기미        2
# No charts were generated by quickchart
