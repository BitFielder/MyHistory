# %%
from IPython.display import YouTubeVideo
YouTubeVideo('etPVpAhOIOU')

# %% [markdown]
# #### 실습과제 : 아래 동요에서 '곰'이 들어가는 단어만 모두 골라내라

# %%
word = '''
곰마세리가 한집에 있어
아빠곰 엄마곰 애기곰
아빠곰은 뚱뚱해
엄마곰은 날씬해
애기곰은 너무 귀여워
히쭉히쭉 잘한다
'''

# %%
for t in word:
    print(t)

# %%
'곰' in '곰세마리가'
# Out:
# True

# %%
#word.split('곰')
files = ['add_2023_01.xlsx', 'add_2024_01.xlsx']
for f in files:
    print(f.split('.')[0].split('_')[1])
# Out:
# 2023
# 2024

# %%
sample = word.split()
sample
# Out:
# ['곰세마리가',
#  '한집에',
#  '있어',
#  '아빠곰',
#  '엄마곰',
#  '애기곰',
#  '아빠곰은',
#  '뚱뚱해',
#  '엄마곰은',
#  '날씬해',
#  '애기곰은',
#  '너무',
#  '귀여워',
#  '히쭉히쭉',
#  '잘한다']

# %%
for word in sample:
    if '곰' in word:
        print(word)
# Out:
# 곰세마리가
# 아빠곰
# 엄마곰
# 애기곰
# 아빠곰은
# 엄마곰은
# 애기곰은

# %%
'아빠곰은'.strip("은")
# Out:
# '아빠곰'

# %%
mylist = []

for word in sample:
    if '곰' in word:
        word = word.strip("은")
        word = word.strip("가")

        mylist.append(word)

# %%
mylist
# Out:
# ['곰세마리', '아빠곰', '엄마곰', '애기곰', '아빠곰', '엄마곰', '애기곰']

# %%
set(mylist)
# Out:
# {'곰세마리', '아빠곰', '애기곰', '엄마곰'}

# %%
bear_uniquie = '//'.join(set(mylist))

# %%
print(a_uniquie)
# Out:
# 애기곰//아빠곰//곰세마리//엄마곰
