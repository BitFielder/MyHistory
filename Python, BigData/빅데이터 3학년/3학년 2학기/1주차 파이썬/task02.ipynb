# %%
txt = '''
I'm your future lover
타락한 밤 너의 ruler
영화 속 달콤한 promise
믿지 않아 let's be honest, yeah
틀린 건 없어 when it feels so right
닿지 않아도 이미 느끼잖아
나쁠 건 없어 when it feels so right
네 위를 봐 I'm your goddess
How many lovers do I go through to find you
How many heartbreaks I take just to get to you
How many lovers do I go through to find you
How many how many how many
Fast Forward
Girl you the one stop
Got it all
Diamond-kissed
Head to toe
Sunshine
Got the glow
Need you bad
Never go
One stop
Domino
That's how quick
You made me fall
So in love yeah
That's so us
How many lovers do I go through to find you
How many heartbreaks I take just to get to you
How many lovers do I go through to find you
How many how many how many
Fast Forward
(How many how many how many)
(How many how many how many)
흔들린 pendulum
너를 부를 때
이 뒤틀린 시간 속
넌 내 눈앞에
Now think of the one you want
Picturing my face
And I'll be the one you on
I'll be the one you on
I'll be the one you want
I can hear you say
Fast Forward
(yeah yeah yeah yeah)
Fast Forward
(yeah yeah yeah yeah)
Fast Forward
'''

# %%
len(txt)
# Out:
# 1040

# %%
txt[0]
# Out:
# '\n'

# %%
txt.split()

# %%
type(txt.split())
# Out:
# list

# %% [markdown]
# 텍스트의 양 끝에 존재하는 ‘공백’과 ‘\n’을 제거한다. strip() 명령어는 중간에 존재하는 ‘공백’과 ‘\n’은 제거하지 않는다

# %%
txt.strip()
# Out:
# "I'm your future lover\n타락한 밤 너의 ruler\n영화 속 달콤한 promise\n믿지 않아 let's be honest, yeah\n틀린 건 없어 when it feels so right\n닿지 않아도 이미 느끼잖아\n나쁠 건 없어 when it feels so right\n네 위를 봐 I'm your goddess\nHow many lovers do I go through to find you\nHow many heartbreaks I take just to get to you\nHow many lovers do I go through to find you\nHow many how many how many\nFast Forward\nGirl you the one stop\nGot it all\nDiamond-kissed\nHead to toe\nSunshine\nGot the glow\nNeed you bad\nNever go\nOne stop\nDomino\nThat's how quick\nYou made me fall\nSo in love yeah\nThat's so us\nHow many lovers do I go through to find you\nHow many heartbreaks I take just to get to you\nHow many lovers do I go through to find you\nHow many how many how many\nFast Forward\n(How many how many how many)\n(How many how many how many)\n흔들린 pendulum\n너를 부를 때\n이 뒤틀린 시간 속\n넌 내 눈앞에\nNow think of the one you want\nPicturing my face\nAnd I'll be the one you on\nI'll be the one you on\nI'll be the one you want\nI can hear you say\nFast Forward\n(yeah yeah yeah yeah)\nFast Forward\n(yeah yeah yeah yeah)\nFast Forward"

# %%
len(txt.strip().split())
# Out:
# 230

# %%
fast_forward = txt.strip().split()

# %%
data = {}
for f in fast_forward:
    if f in data:
        data[f] = data[f] + 1
    else:
        data[f] = 1
print(data)
# Out:
# {"I'm": 2, 'your': 2, 'future': 1, 'lover': 1, '타락한': 1, '밤': 1, '너의': 1, 'ruler': 1, '영화': 1, '속': 2, '달콤한': 1, 'promise': 1, '믿지': 1, '않아': 1, "let's": 1, 'be': 4, 'honest,': 1, 'yeah': 6, '틀린': 1, '건': 2, '없어': 2, 'when': 2, 'it': 3, 'feels': 2, 'so': 3, 'right': 2, '닿지': 1, '않아도': 1, '이미': 1, '느끼잖아': 1, '나쁠': 1, '네': 1, '위를': 1, '봐': 1, 'goddess': 1, 'How': 8, 'many': 16, 'lovers': 4, 'do': 4, 'I': 7, 'go': 5, 'through': 4, 'to': 9, 'find': 4, 'you': 13, 'heartbreaks': 2, 'take': 2, 'just': 2, 'get': 2, 'how': 9, 'Fast': 5, 'Forward': 5, 'Girl': 1, 'the': 6, 'one': 5, 'stop': 2, 'Got': 2, 'all': 1, 'Diamond-kissed': 1, 'Head': 1, 'toe': 1, 'Sunshine': 1, 'glow': 1, 'Need': 1, 'bad': 1, 'Never': 1, 'One': 1, 'Domino': 1, "That's": 2, 'quick': 1, 'You': 1, 'made': 1, 'me': 1, 'fall': 1, 'So': 1, 'in': 1, 'love': 1, 'us': 1, '(How': 2, 'many)': 2, '흔들린': 1, 'pendulum': 1, '너를': 1, '부를': 1, '때': 1, '이': 1, '뒤틀린': 1, '시간': 1, '넌': 1, '내': 1, '눈앞에': 1, 'Now': 1, 'think': 1, 'of': 1, 'want': 2, 'Picturing': 1, 'my': 1, 'face': 1, 'And': 1, "I'll": 3, 'on': 2, 'can': 1, 'hear': 1, 'say': 1, '(yeah': 2, 'yeah)': 2}

# %%
df = pd.DataFrame(data.items(), columns=['Word', 'Frequency'])
df
# Out:
#        Word  Frequency
# 0       I'm          2
# 1      your          2
# 2    future          1
# 3     lover          1
# 4       타락한          1
# ..      ...        ...
# 101     can          1
# 102    hear          1
# 103     say          1
# 104   (yeah          2
# 105   yeah)          2
#
# [106 rows x 2 columns]

# %%
df.sort_values('Frequency', ascending=False)
# Out:
#       Word  Frequency
# 36    many         16
# 44     you         13
# 42      to          9
# 49     how          9
# 35     How          8
# ..     ...        ...
# 67  Domino          1
# 8       영화          1
# 69   quick          1
# 33       봐          1
# 70     You          1
#
# [106 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['Frequency'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *['Frequency'], **{})
# chart
