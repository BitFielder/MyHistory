# %% [markdown]
# # 1. sqlite3와 연동하기
# - SQLite는 MySQL나 PostgreSQL와 같은 데이터베이스 관리 시스템
# - 서버가 아니라 응용 프로그램에 넣어 사용하는 비교적 가벼운 데이터베이스
# - '에스큐엘라이트'또는 '시퀄라이트'라고 읽는다. 위키백과
# - https://www.sqlite.org/index.html
#
# - https://www.youtube.com/watch?v=pO-EeLn9IsU&t=126s
# - https://www.youtube.com/watch?v=WaKOnXTKyhU (각자 따라해보기)
#
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSvu_GXk-xlsx0iuMCsYcd6sIwHtalnigNgrmLVHyJf6Q&s'>

# %%
import sqlite3

# Connect to a database (creates a new one if it doesn't exist)
conn = sqlite3.connect('example.db')

# %% [markdown]
# > ### **DB 만들기**
# >> - 'example.db'라는 이름의 SQLite 데이터베이스 파일과 연결을 만들고,
# 만약 해당 파일이 이미 존재하지 않으면 새로운 데이터베이스 파일이 생성
# - 이 연결 객체를 사용하여 데이터베이스와 상호 작용할 수 있음

# %%
# Create a cursor object to execute SQL commands
cursor = conn.cursor()

# %% [markdown]
# >> - 커서(conn.cursor())는 데이터베이스 연결(conn)과 상호 작용하여 데이터베이스에 쿼리를 실행하고 결과를 처리하는 역할 수행
# - 커서(cursor)를 사용하여 SQL 쿼리를 실행하고, 결과 집합을 탐색하며, 데이터를 추가, 수정 또는 삭제하는 등의 작업을 수행

# %% [markdown]
# > ### **Create Table**

# %%
'''
# Create a new SQLite database file
conn = sqlite3.connect('new_database.db')
cursor = conn.cursor()
'''

# %%
# Create the table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS users (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT NOT NULL,
        age INTEGER
    )
''')

# %% [markdown]
# ### CREATE TABLE 문을 사용하여 'users'라는 테이블을 생성하고 그 구조를 정의합니다.
# >> - id INTEGER PRIMARY KEY AUTOINCREMENT: 'id'라는 이름의 INTEGER 데이터형 열을 생성하며, 이 열은 주요 키(primary key)로 설정됩니다. AUTOINCREMENT 키워드는 자동으로 고유한 값을 생성해주는 역할을 합니다.
# >> - name TEXT NOT NULL: 'name'이라는 이름의 TEXT 데이터형 열을 생성하며, 이 열에는 NULL 값이 들어갈 수 없도록 NOT NULL 제약 조건이 설정됩니다.
# >> - age INTEGER: 'age'라는 이름의 INTEGER 데이터형 열을 생성합니다.

# %% [markdown]
# >## **Insert data into the table**

# %%
cursor.execute("INSERT INTO users (name, age) VALUES (?, ?)", ('John Doe', 30))
cursor.execute("INSERT INTO users (name, age) VALUES (?, ?)", ('Jane Smith', 25))
conn.commit()

# %% [markdown]
# > ## **Retrieve data from the table**

# %%
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()

# Display the retrieved data
for row in rows:
    print(f"ID: {row[0]}, Name: {row[1]}, Age: {row[2]}")

# Close the cursor and the connection
cursor.close()
conn.close()
# Out:
# ID: 1, Name: John Doe, Age: 30
# ID: 2, Name: Jane Smith, Age: 25

# %%
'''conn = sqlite3.connect('new_database.db')'''

# %%
query = "SELECT * FROM users"

import pandas as pd
df = pd.read_sql_query(query, conn)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-8-4aa4d0ffd3f4> in <cell line: 4>()
#       2
#       3 import pandas as pd
# ----> 4 df = pd.read_sql_query(query, conn)
#       5 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     395     """
#     396     pandas_sql = pandasSQL_builder(con)
# --> 397     return pandas_sql.read_query(
#     398         sql,
#     399         index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2076
#    2077         args = _convert_params(sql, params)
# -> 2078         cursor = self.execute(*args)
#    2079         columns = [col_desc[0] for col_desc in cursor.description]
#    2080
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2014
#    2015     def execute(self, *args, **kwargs):
# -> 2016         cur = self.con.cursor()
#    2017         try:
#    2018             cur.execute(*args, **kwargs)
#
# ProgrammingError: Cannot operate on a closed database.

# %%
conn

# %%
cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-11-4bc25eab5223> in <cell line: 1>()
# ----> 1 cursor = conn.cursor()
#
# ProgrammingError: Cannot operate on a closed database.

# %%
conn = sqlite3.connect('example.db')
cursor = conn.cursor()

# %%
query = "SELECT * FROM users"

import pandas as pd
df = pd.read_sql_query(query, conn)
df
# Out:
#    id        name  age
# 0   1    John Doe   30
# 1   2  Jane Smith   25

# %% [markdown]
# ## 실전문제: fake 모듈을 사용하여 가상의 데이터(성명, 주소, 이메일) 1만개를 만들고  db에 저장하라

# %%
! pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-19.3.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Installing collected packages: Faker
# Successfully installed Faker-19.3.1

# %%
# Establish a connection to the SQLite database
conn = sqlite3.connect('example_email.db')

# Create a cursor object to execute SQL commands
cursor = conn.cursor()

# Create a table to store the fake data
cursor.execute('''
    CREATE TABLE IF NOT EXISTS users (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT NOT NULL,
        email TEXT NOT NULL,
        address TEXT
    )
''')

# %%
from faker import Faker

# Initialize Faker to generate fake data
fake = Faker()

# Generate and insert 10000 fake data records into the table
for _ in range(10000):
    name = fake.name()
    email = fake.email()
    address = fake.address()
    cursor.execute("INSERT INTO users (name, email, address) VALUES (?, ?, ?)", (name, email, address))



#cursor.execute("INSERT INTO users (name, age) VALUES (?, ?)", ('John Doe', 30))

conn.commit()

# %%
# Retrieve the data from the table into a pandas DataFrame
df = pd.read_sql_query("SELECT * FROM users", conn)

# Close the cursor and the connection
cursor.close()
conn.close()

# %%
# Display the DataFrame
df
# Out:
#          id             name                       email  \
# 0         1     James Gibson       michael86@example.com
# 1         2  William Hartman  brewerkimberly@example.com
# 2         3   Stephanie Nash       michael74@example.com
# 3         4  Rebecca Parrish  johnsonphillip@example.net
# 4         5     Karen Brooks     watsonjason@example.net
# ...     ...              ...                         ...
# 9995   9996  Alyssa Martinez      michelle60@example.net
# 9996   9997    Leslie Vaughn       kchambers@example.net
# 9997   9998     Melissa Webb       monique17@example.org
# 9998   9999        Anna Ward       michael27@example.com
# 9999  10000       Eric White       michael95@example.org
#
#                                                 address
# 0     452 Tate Knolls Apt. 925\nNorth Kevinborough, ...
# 1       9707 Janet View Suite 416\nEddieville, SD 56734
# 2        802 Stephen Fields\nSouth Haileyport, DC 81051
# 3     1289 Donald Throughway Apt. 519\nWest Taylor, ...
# 4          58918 Wallace Mills\nEdwardborough, OR 53595
# ...                                                 ...
# 9995  72739 Klein Street Suite 862\nSouth Victoria, ...
# 9996                   Unit 2410 Box 2059\nDPO AA 38348
# 9997    69813 Taylor Glen Apt. 589\nEast Ryan, WV 75856
# 9998  5402 Taylor Islands Apt. 812\nKarinaburgh, PA ...
# 9999   9348 Tony Pass Suite 174\nEvansborough, MA 49889
#
# [10000 rows x 4 columns]

# %% [markdown]
# # 2. MySQL과 연동하기(Maria DB 등등 연동 가능)
# - https://www.youtube.com/watch?v=QluBbR2Hpc4
# -local에서만 접속이 가능하고 외부에서(clould)에서 접속이 불가

# %%
# !pip install mysql-connector
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mysql-connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 76.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mysql-connector
#   Building wheel for mysql-connector (setup.py) ... done
#   Created wheel for mysql-connector: filename=mysql_connector-2.2.9-cp310-cp310-linux_x86_64.whl size=247953 sha256=7494c73909e559a2c9d138e21acf7e8a47fe46d12f591defa7dd5e4a823da67f
#   Stored in directory: /root/.cache/pip/wheels/76/48/9b/da67ff1a18fe8e9d428f9b1a177716d4a7d363d2bbe83bf6cf
# Successfully built mysql-connector
# Installing collected packages: mysql-connector
# Successfully installed mysql-connector-2.2.9

# %%
import mysql.connector

# %%
import mysql.connector

# Establish a connection to the MySQL server
myconn = mysql.connector.connect(
    host= '34.64.146.102', #'Mysql@127.0.0.1',
    #port = 3306,
    database='db_shop',
    user='ancestor9',
    password='0000',
)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-5-f47a91d0cf86> in <cell line: 4>()
#       2
#       3 # Establish a connection to the MySQL server
# ----> 4 myconn = mysql.connector.connect(
#       5     host= '34.64.146.102', #'Mysql@127.0.0.1',
#       6     #port = 3306,
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# --> 179         return MySQLConnection(*args, **kwargs)
#     180 Connect = connect  # pylint: disable=C0103
#     181
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection.py in __init__(self, *args, **kwargs)
#      93
#      94         if len(kwargs) > 0:
# ---> 95             self.connect(**kwargs)
#      96
#      97     def _do_handshake(self):
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#     714
#     715         self.disconnect()
# --> 716         self._open_connection()
#     717         self._post_connection()
#     718
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection.py in _open_connection(self)
#     204         self._protocol = MySQLProtocol()
#     205         self._socket = self._get_connection()
# --> 206         self._socket.open_connection()
#     207         self._do_handshake()
#     208         self._do_auth(self._user, self._password,
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/network.py in open_connection(self)
#     509             self.sock.connect(sockaddr)
#     510         except IOError as err:
# --> 511             raise errors.InterfaceError(
#     512                 errno=2003, values=(self.get_address(), _strioerror(err)))
#     513         except Exception as err:
#
# InterfaceError: 2003: Can't connect to MySQL server on '34.64.146.102:3306' (110 Connection timed out)

# %%
# Continue with your code using the established connection

# Remember to close the connection when finished
myconn.close()

# %%
# Out:
# '/content'
