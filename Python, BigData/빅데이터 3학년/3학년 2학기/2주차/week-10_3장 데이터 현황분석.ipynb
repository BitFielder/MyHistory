# %% [markdown]
# # **3장 데이터 현황분석**

# %% [markdown]
# # **3.1 데이터 불러오기**

# %%
# 한 셀안의 명령어 겨로가를 모두 보여준다
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import numpy as np
import pandas as pd
np.__version__
pd.__version__
# Out:
# '1.5.3'

# %%
# %time
df = pd.read_excel('MCR2019_최종.xlsx', header=1)
df.shape
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1650                 ext = "xls"
#    1651             else:
# -> 1652                 ext = inspect_excel_format(
#    1653                     content_or_path=path_or_buffer, storage_options=storage_options
#    1654                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1523         content_or_path = BytesIO(content_or_path)
#    1524
# -> 1525     with get_handle(
#    1526         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         else:
#     864             # Binary mode
# --> 865             handle = open(handle, ioargs.mode)
#     866         handles.append(handle)
#     867
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MCR2019_최종.xlsx'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-183bd91c6227> in <cell line: 2>()
#       1 get_ipython().run_line_magic('time', "df = pd.read_excel('MCR2019_최종.xlsx', header=1)")
# ----> 2 df.shape
#       3 df.head()
#
# NameError: name 'df' is not defined

# %%
selected_col = ([1, 3, 4, 5, 6, 9, 11, 14, 16] + list(np.arange(44,50)) +
                list(np.arange(293,305)) + list(np.arange(311,321)) + [379])
# %time df = pd.read_excel('MCR2019_최종.xlsx', header= 1, usecols= selected_col)

# pickle 로 압축하여 저장하기
# %time df.to_pickle('MCR2019.pkl') #
# Out:
# CPU times: user 1min 29s, sys: 433 ms, total: 1min 30s
# Wall time: 1min 30s
# CPU times: user 3.8 ms, sys: 1.02 ms, total: 4.82 ms
# Wall time: 4.9 ms

# %%
# %time df = pd.read_pickle('MCR2019.pkl')
df.shape
df.head()
# Out:
# CPU times: user 3.75 ms, sys: 999 µs, total: 4.75 ms
# Wall time: 4.8 ms
# (4000, 38)
#    성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0   1      14       1   6             6     8      3      2      99
# 1   1      14       1   6             6     8      1      2      99
# 2   1      14       1   6             6     8      2      2      99
# 3   1      14       1   6             8     8      1      2      99
# 4   1      14       1   6             9     8      1      2      99
#
#    평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.1  \
# 0             0.0  ...                           9.0
# 1            30.0  ...                           6.0
# 2            90.0  ...                           4.0
# 3             NaN  ...                           NaN
# 4             0.0  ...                           5.0
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  \
# 0                          10.0                            13
# 1                          11.0                           NaN
# 2                          12.0                            14
# 3                           NaN                           NaN
# 4                          10.0                            11
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    PPL(간접광고) 평가 - 제품/브랜드 구매의향
# 0                           4
# 1                           2
# 2                           5
# 3                           2
# 4                           3
#
# [5 rows x 38 columns]

# %% [markdown]
# ### compress-pickle
# - https://pypi.org/project/compress-pickle/

# %%
df.to_pickle(f'MCR2019_gzip.pkl', compression='gzip')

# %%
# %time df = pd.read_pickle('MCR2019_gzip.pkl', compression='gzip')
df.shape
df.head()
# Out:
# CPU times: user 11 ms, sys: 0 ns, total: 11 ms
# Wall time: 11.9 ms
# (4000, 38)
#    성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0   1      14       1   6             6     8      3      2      99
# 1   1      14       1   6             6     8      1      2      99
# 2   1      14       1   6             6     8      2      2      99
# 3   1      14       1   6             8     8      1      2      99
# 4   1      14       1   6             9     8      1      2      99
#
#    평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.1  \
# 0             0.0  ...                           9.0
# 1            30.0  ...                           6.0
# 2            90.0  ...                           4.0
# 3             NaN  ...                           NaN
# 4             0.0  ...                           5.0
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  \
# 0                          10.0                            13
# 1                          11.0                           NaN
# 2                          12.0                            14
# 3                           NaN                           NaN
# 4                          10.0                            11
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    PPL(간접광고) 평가 - 제품/브랜드 구매의향
# 0                           4
# 1                           2
# 2                           5
# 3                           2
# 4                           3
#
# [5 rows x 38 columns]

# %%
# 데이터 현황파악
df.describe()
# Out:
#                 성별       연령(1세)       지역(권역)           직업  가구 월평균 소득(1)  \
# count  4000.000000  4000.000000  4000.000000  4000.000000   4000.000000
# mean      1.494500    41.394500     2.945000     3.979000      5.645500
# std       0.500032    15.151741     1.758621     1.710933      2.870608
# min       1.000000    13.000000     1.000000     1.000000      1.000000
# 25%       1.000000    28.000000     2.000000     3.000000      4.000000
# 50%       1.000000    43.000000     2.000000     4.000000      6.000000
# 75%       2.000000    54.000000     5.000000     5.000000      7.000000
# max       2.000000    69.000000     7.000000     7.000000     99.000000
#
#              최종학력        주거 형태        결혼 여부       자녀 총 수  평일 인터넷 이용시간(분)  ...  \
# count  4000.00000  4000.000000  4000.000000  4000.000000     2603.000000  ...
# mean      5.72725     1.268750     1.412000    38.854750       65.366884  ...
# std       2.20365     0.567982     0.556177    47.194316       61.173436  ...
# min       1.00000     1.000000     1.000000     1.000000        0.000000  ...
# 25%       4.00000     1.000000     1.000000     2.000000       30.000000  ...
# 50%       5.00000     1.000000     1.000000     2.000000       60.000000  ...
# 75%       6.00000     1.000000     2.000000    99.000000       60.000000  ...
# max      12.00000     5.000000     3.000000    99.000000      720.000000  ...
#
#        즐겨 보는 TV 프로그램 장르.1  즐겨 보는 TV 프로그램 장르.2  즐겨 보는 TV 프로그램 장르.3  \
# count         3857.000000         3415.000000         2570.000000
# mean             4.228934            5.846852            7.110117
# std              2.191840            2.260231            2.168984
# min              1.000000            1.000000            1.000000
# 25%              2.000000            4.000000            6.000000
# 50%              4.000000            6.000000            7.000000
# 75%              6.000000            7.000000            8.000000
# max             17.000000           16.000000           16.000000
#
#        즐겨 보는 TV 프로그램 장르.4  즐겨 보는 TV 프로그램 장르.5  즐겨 보는 TV 프로그램 장르.6  \
# count         1576.000000          877.000000          453.000000
# mean             8.182741            9.002281            9.732892
# std              2.087205            2.289542            2.355881
# min              4.000000            4.000000            4.000000
# 25%              7.000000            7.000000            8.000000
# 50%              8.000000            9.000000            9.000000
# 75%              9.000000           10.000000           10.000000
# max             17.000000           16.000000           17.000000
#
#        TV 시청 시 즐겨 보는 국내 드라마 장르-내용  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.1  \
# count                 2857.000000                   2476.000000
# mean                     2.382919                      5.133279
# std                      2.190114                      2.861378
# min                      1.000000                      1.000000
# 25%                      1.000000                      4.000000
# 50%                      1.000000                      4.000000
# 75%                      4.000000                      6.000000
# max                     16.000000                     15.000000
#
#        TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  PPL(간접광고) 평가 - 제품/브랜드 구매의향
# count                   1730.000000                 4000.000000
# mean                       7.577457                    3.131000
# std                        3.456423                    1.073605
# min                        2.000000                    1.000000
# 25%                        5.000000                    2.000000
# 50%                        7.000000                    3.000000
# 75%                       10.000000                    4.000000
# max                       16.000000                    6.000000
#
# [8 rows x 26 columns]

# %%
df = df[df.columns[0:11]]

# %%
df[df['성별'] == 1].head()
# Out:
#    성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0   1      14       1   6             6     8      3      2      99
# 1   1      14       1   6             6     8      1      2      99
# 2   1      14       1   6             6     8      2      2      99
# 3   1      14       1   6             8     8      1      2      99
# 4   1      14       1   6             9     8      1      2      99
#
#    평일 인터넷 이용시간(분)  토요일 인터넷 이용시간(분)
# 0             0.0            120.0
# 1            30.0             40.0
# 2            90.0             60.0
# 3             NaN              NaN
# 4             0.0             60.0

# %%
df[(df['성별'] == 1) & (df['평일 인터넷 이용시간(분)'] >= 100)]
# Out:
#       성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 6      1      13       1   6             5     8      1      2      99
# 8      1      15       1   6             6     8      1      2      99
# 9      1      15       1   6             5     8      1      2      99
# 16     1      16       1   6             6     9      1      2      99
# 18     1      17       1   6             6     3      1      2      99
# ...   ..     ...     ...  ..           ...   ...    ...    ...     ...
# 3966   1      31       4   3             4     6      1      1       1
# 3968   1      36       4   3             4     4      2      1       1
# 3971   1      43       4   2             6     6      1      1       1
# 3973   1      48       4   2             5     7      1      1       2
# 3975   1      53       4   1             6     7      1      1       2
#
#       평일 인터넷 이용시간(분)  토요일 인터넷 이용시간(분)
# 6              120.0            120.0
# 8              120.0            180.0
# 9              180.0            180.0
# 16             120.0            120.0
# 18             180.0            180.0
# ...              ...              ...
# 3966           180.0            180.0
# 3968           120.0              0.0
# 3971           120.0            120.0
# 3973           120.0            120.0
# 3975           120.0            120.0
#
# [330 rows x 11 columns]

# %%
df[(df['성별']==1) & (df['평일 인터넷 이용시간(분)']>=100)].sort_values('연령(1세)', ascending=False)
# Out:
#       성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 453    1      66       1   2             6     4      1      1       2
# 2643   1      65       2   1            11     6      1      1       3
# 1094   1      65       5   4             5     5      1      1       2
# 1583   1      64       2   3             3     4      1      1       2
# 437    1      64       1   4             3     4      1      3       2
# ...   ..     ...     ...  ..           ...   ...    ...    ...     ...
# 1732   1      13       4   6             5     8      1      2      99
# 2128   1      13       2   6             6     8      1      2      99
# 3752   1      13       5   6             6     8      1      2      99
# 1463   1      13       2   6             5     8      1      2      99
# 6      1      13       1   6             5     8      1      2      99
#
#       평일 인터넷 이용시간(분)  토요일 인터넷 이용시간(분)
# 453            210.0             30.0
# 2643           180.0             30.0
# 1094           120.0             30.0
# 1583           120.0            120.0
# 437            120.0             60.0
# ...              ...              ...
# 1732           120.0             60.0
# 2128           120.0            120.0
# 3752           240.0            240.0
# 1463           120.0            120.0
# 6              120.0            120.0
#
# [330 rows x 11 columns]

# %%
pd.pivot_table(df, values='평일 인터넷 이용시간(분)', index= '성별', columns= '직업')
# Out:
# 직업          1          2          3      4          5          6          7
# 성별
# 1   73.904494  80.313390  65.957447  51.94        NaN  77.427746  66.153846
# 2   71.200000  64.487069  52.406417  47.50  49.212544  65.736301  68.636364

# %%
df.groupby(['성별', '직업'])['평일 인터넷 이용시간(분)'].mean().unstack()
# Out:
# 직업          1          2          3      4          5          6          7
# 성별
# 1   73.904494  80.313390  65.957447  51.94        NaN  77.427746  66.153846
# 2   71.200000  64.487069  52.406417  47.50  49.212544  65.736301  68.636364

# %%
import matplotlib.pyplot as plt
df.groupby('연령(1세)')['평일 인터넷 이용시간(분)'].size().plot(figsize=(20,4))
plt.show();

# %% [markdown]
# ### <font color='brown'> **한글 깨지지 않게 하는 실습_co lab 환경에서**

# %% [markdown]
# # **3.2 데이터 분석**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %time df = pd.read_pickle('MCR2019_gzip.pkl', compression='gzip')
df.head()
# Out:
# CPU times: user 9.91 ms, sys: 1 ms, total: 10.9 ms
# Wall time: 14 ms
#    성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0   1      14       1   6             6     8      3      2      99
# 1   1      14       1   6             6     8      1      2      99
# 2   1      14       1   6             6     8      2      2      99
# 3   1      14       1   6             8     8      1      2      99
# 4   1      14       1   6             9     8      1      2      99
#
#    평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.1  \
# 0             0.0  ...                           9.0
# 1            30.0  ...                           6.0
# 2            90.0  ...                           4.0
# 3             NaN  ...                           NaN
# 4             0.0  ...                           5.0
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  \
# 0                          10.0                            13
# 1                          11.0                           NaN
# 2                          12.0                            14
# 3                           NaN                           NaN
# 4                          10.0                            11
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    PPL(간접광고) 평가 - 제품/브랜드 구매의향
# 0                           4
# 1                           2
# 2                           5
# 3                           2
# 4                           3
#
# [5 rows x 38 columns]

# %%
df.isnull()
# Out:
#          성별  연령(1세)  지역(권역)     직업  가구 월평균 소득(1)   최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0     False   False   False  False         False  False  False  False   False
# 1     False   False   False  False         False  False  False  False   False
# 2     False   False   False  False         False  False  False  False   False
# 3     False   False   False  False         False  False  False  False   False
# 4     False   False   False  False         False  False  False  False   False
# ...     ...     ...     ...    ...           ...    ...    ...    ...     ...
# 3995  False   False   False  False         False  False  False  False   False
# 3996  False   False   False  False         False  False  False  False   False
# 3997  False   False   False  False         False  False  False  False   False
# 3998  False   False   False  False         False  False  False  False   False
# 3999  False   False   False  False         False  False  False  False   False
#
#       평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.1  \
# 0              False  ...                         False
# 1              False  ...                         False
# 2              False  ...                         False
# 3               True  ...                          True
# 4              False  ...                         False
# ...              ...  ...                           ...
# 3995            True  ...                         False
# 3996            True  ...                         False
# 3997            True  ...                         False
# 3998            True  ...                         False
# 3999            True  ...                         False
#
#       TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  \
# 0                            False                         False
# 1                            False                          True
# 2                            False                         False
# 3                             True                          True
# 4                            False                         False
# ...                            ...                           ...
# 3995                         False                          True
# 3996                          True                          True
# 3997                         False                         False
# 3998                          True                          True
# 3999                          True                          True
#
#       TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  \
# 0                             True                          True
# 1                             True                          True
# 2                             True                          True
# 3                             True                          True
# 4                             True                          True
# ...                            ...                           ...
# 3995                          True                          True
# 3996                          True                          True
# 3997                          True                          True
# 3998                          True                          True
# 3999                          True                          True
#
#       TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  \
# 0                             True                          True
# 1                             True                          True
# 2                             True                          True
# 3                             True                          True
# 4                             True                          True
# ...                            ...                           ...
# 3995                          True                          True
# 3996                          True                          True
# 3997                          True                          True
# 3998                          True                          True
# 3999                          True                          True
#
#       TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  \
# 0                             True                          True
# 1                             True                          True
# 2                             True                          True
# 3                             True                          True
# 4                             True                          True
# ...                            ...                           ...
# 3995                          True                          True
# 3996                          True                          True
# 3997                          True                          True
# 3998                          True                          True
# 3999                          True                          True
#
#       PPL(간접광고) 평가 - 제품/브랜드 구매의향
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 3995                       False
# 3996                       False
# 3997                       False
# 3998                       False
# 3999                       False
#
# [4000 rows x 38 columns]

# %%
df.isnull().sum()
# Out:
# 성별                                 0
# 연령(1세)                             0
# 지역(권역)                             0
# 직업                                 0
# 가구 월평균 소득(1)                       0
# 최종학력                               0
# 주거 형태                              0
# 결혼 여부                              0
# 자녀 총 수                             0
# 평일 인터넷 이용시간(분)                  1397
# 토요일 인터넷 이용시간(분)                 1397
# 일요일 인터넷 이용시간(분)                 1397
# 평일 하루 평균 모바일 인터넷 이용 시간(분)        186
# 토요일 하루 평균 모바일 인터넷 이용 시간(분)       186
# 일요일 하루 평균 모바일 인터넷 이용 시간(분)       186
# 즐겨 보는 TV 프로그램 장르                   0
# 즐겨 보는 TV 프로그램 장르.1               143
# 즐겨 보는 TV 프로그램 장르.2               585
# 즐겨 보는 TV 프로그램 장르.3              1430
# 즐겨 보는 TV 프로그램 장르.4              2424
# 즐겨 보는 TV 프로그램 장르.5              3123
# 즐겨 보는 TV 프로그램 장르.6              3547
# 즐겨 보는 TV 프로그램 장르.7              3758
# 즐겨 보는 TV 프로그램 장르.8              3861
# 즐겨 보는 TV 프로그램 장르.9              3916
# 즐겨 보는 TV 프로그램 장르.10             3956
# 즐겨 보는 TV 프로그램 장르.11             3977
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용      1143
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.1    1524
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2    2270
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3    3038
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4    3490
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5    3706
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6    3825
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7    3892
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8    3945
# TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9    3978
# PPL(간접광고) 평가 - 제품/브랜드 구매의향         0
# dtype: int64

# %%
# 결측치 비율 구하기
(df.isnull().sum()/df.shape[0]).plot(kind='bar', rot=60, figsize=(20,5))
# Out:
# <Axes: >

# %%
df['즐겨 보는 TV 프로그램 장르.11'].isnull().sum()
# Out:
# 3977

# %%
df['즐겨 보는 TV 프로그램 장르.11'].value_counts()
# Out:
# 16        13
# 15         4
# 12         3
# 13         2
# #NULL!     1
# Name: 즐겨 보는 TV 프로그램 장르.11, dtype: int64

# %%
df['즐겨 보는 TV 프로그램 장르.11'].value_counts(dropna=False)
# Out:
# NaN       3977
# 16          13
# 15           4
# 12           3
# 13           2
# #NULL!       1
# Name: 즐겨 보는 TV 프로그램 장르.11, dtype: int64

# %%
df['직업'].value_counts()
# Out:
# 6    752
# 3    746
# 2    675
# 4    661
# 5    655
# 1    280
# 7    231
# Name: 직업, dtype: int64

# %%
df['직업'].value_counts(normalize=True)
# Out:
# 6    0.18800
# 3    0.18650
# 2    0.16875
# 4    0.16525
# 5    0.16375
# 1    0.07000
# 7    0.05775
# Name: 직업, dtype: float64

# %%
map_job ={1:'행정관리/전문직', 2:'사무직', 3:'판매/서비스직', 4:'기능/노무직',
          5:'전업주부', 6:'학생(재수생포함)', 7:'무직/기타'}

# %%
df['직업'].apply(lambda x: map_job[x] if x in map_job.keys() else x)
df['직업'].value_counts(normalize=True).rename(index=map_job).plot(kind='bar', rot=360, figsize=(20,5))
# Out:
# 0       학생(재수생포함)
# 1       학생(재수생포함)
# 2       학생(재수생포함)
# 3       학생(재수생포함)
# 4       학생(재수생포함)
#           ...
# 3995       기능/노무직
# 3996         전업주부
# 3997       기능/노무직
# 3998       기능/노무직
# 3999         전업주부
# Name: 직업, Length: 4000, dtype: object
# <Axes: >

# %%
df[df.columns[0:12]].hist(bins=20, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': '성별'}>,
#         <Axes: title={'center': '연령(1세)'}>,
#         <Axes: title={'center': '지역(권역)'}>],
#        [<Axes: title={'center': '직업'}>,
#         <Axes: title={'center': '가구 월평균 소득(1)'}>,
#         <Axes: title={'center': '최종학력'}>],
#        [<Axes: title={'center': '주거 형태'}>,
#         <Axes: title={'center': '결혼 여부'}>,
#         <Axes: title={'center': '자녀 총 수'}>],
#        [<Axes: title={'center': '평일 인터넷 이용시간(분)'}>,
#         <Axes: title={'center': '토요일 인터넷 이용시간(분)'}>,
#         <Axes: title={'center': '일요일 인터넷 이용시간(분)'}>]], dtype=object)

# %%
df['구매'] = df.iloc[:,-1]

# %%
map_dict={1:'1.전혀 그렇지 않다', 2:'2.그렇지 않다', 3:'3.그렇지 않은 편이다',
          4:'4.그런 편이다', 5:'5.그렇다', 6:'6.매우 그렇다'}

tf = df['구매'].value_counts(normalize=True).rename(index=map_dict)
tf.sort_index(inplace=True)

# %%
tf.plot(kind='bar', rot=360, figsize=(20,5))
# Out:
# <Axes: >

# %%
df.loc[:, '성별' : '결혼 여부']
# Out:
#       성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부
# 0      1      14       1   6             6     8      3      2
# 1      1      14       1   6             6     8      1      2
# 2      1      14       1   6             6     8      2      2
# 3      1      14       1   6             8     8      1      2
# 4      1      14       1   6             9     8      1      2
# ...   ..     ...     ...  ..           ...   ...    ...    ...
# 3995   2      58       4   4             1     3      1      3
# 3996   2      63       4   5             7     4      1      1
# 3997   2      61       4   4             4     3      2      1
# 3998   2      67       4   4             2     3      1      3
# 3999   2      65       4   5             4     4      1      1
#
# [4000 rows x 8 columns]

# %%
df.iloc[:, 0:8]
# Out:
#       성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부
# 0      1      14       1   6             6     8      3      2
# 1      1      14       1   6             6     8      1      2
# 2      1      14       1   6             6     8      2      2
# 3      1      14       1   6             8     8      1      2
# 4      1      14       1   6             9     8      1      2
# ...   ..     ...     ...  ..           ...   ...    ...    ...
# 3995   2      58       4   4             1     3      1      3
# 3996   2      63       4   5             7     4      1      1
# 3997   2      61       4   4             4     3      2      1
# 3998   2      67       4   4             2     3      1      3
# 3999   2      65       4   5             4     4      1      1
#
# [4000 rows x 8 columns]

# %%
df.loc[df.성별 == 1]
# Out:
#       성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0      1      14       1   6             6     8      3      2      99
# 1      1      14       1   6             6     8      1      2      99
# 2      1      14       1   6             6     8      2      2      99
# 3      1      14       1   6             8     8      1      2      99
# 4      1      14       1   6             9     8      1      2      99
# ...   ..     ...     ...  ..           ...   ...    ...    ...     ...
# 3975   1      53       4   1             6     7      1      1       2
# 3976   1      58       4   4             5     4      1      1       1
# 3977   1      56       4   7             4     6      1      1      99
# 3978   1      61       4   4             4     4      1      1       2
# 3979   1      68       4   7             2     6      1      3      99
#
#       평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  \
# 0                0.0  ...                          10.0
# 1               30.0  ...                          11.0
# 2               90.0  ...                          12.0
# 3                NaN  ...                           NaN
# 4                0.0  ...                          10.0
# ...              ...  ...                           ...
# 3975           120.0  ...                           NaN
# 3976            60.0  ...                           NaN
# 3977             NaN  ...                           NaN
# 3978             NaN  ...                           NaN
# 3979             NaN  ...                           NaN
#
#       TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  \
# 0                               13                           NaN
# 1                              NaN                           NaN
# 2                               14                           NaN
# 3                              NaN                           NaN
# 4                               11                           NaN
# ...                            ...                           ...
# 3975                           NaN                           NaN
# 3976                           NaN                           NaN
# 3977                           NaN                           NaN
# 3978                           NaN                           NaN
# 3979                           NaN                           NaN
#
#       TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 3975                           NaN                           NaN
# 3976                           NaN                           NaN
# 3977                           NaN                           NaN
# 3978                           NaN                           NaN
# 3979                           NaN                           NaN
#
#       TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 3975                           NaN                           NaN
# 3976                           NaN                           NaN
# 3977                           NaN                           NaN
# 3978                           NaN                           NaN
# 3979                           NaN                           NaN
#
#       TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  PPL(간접광고) 평가 - 제품/브랜드 구매의향  구매
# 0                              NaN                           4   4
# 1                              NaN                           2   2
# 2                              NaN                           5   5
# 3                              NaN                           2   2
# 4                              NaN                           3   3
# ...                            ...                         ...  ..
# 3975                           NaN                           5   5
# 3976                           NaN                           1   1
# 3977                           NaN                           4   4
# 3978                           NaN                           2   2
# 3979                           NaN                           5   5
#
# [2022 rows x 39 columns]

# %%
df.loc[df.성별 == 1, ['성별', '직업', '최종학력', '주거 형태']]
# Out:
#       성별  직업  최종학력  주거 형태
# 0      1   6     8      3
# 1      1   6     8      1
# 2      1   6     8      2
# 3      1   6     8      1
# 4      1   6     8      1
# ...   ..  ..   ...    ...
# 3975   1   1     7      1
# 3976   1   4     4      1
# 3977   1   7     6      1
# 3978   1   4     4      1
# 3979   1   7     6      1
#
# [2022 rows x 4 columns]

# %%
df.iloc[:, [0,3,5,6]]
# Out:
#       성별  직업  최종학력  주거 형태
# 0      1   6     8      3
# 1      1   6     8      1
# 2      1   6     8      2
# 3      1   6     8      1
# 4      1   6     8      1
# ...   ..  ..   ...    ...
# 3995   2   4     3      1
# 3996   2   5     4      1
# 3997   2   4     3      2
# 3998   2   4     3      1
# 3999   2   5     4      1
#
# [4000 rows x 4 columns]

# %%
df.성별.value_counts(dropna=False)
# Out:
# 1    2022
# 2    1978
# Name: 성별, dtype: int64

# %%
df.loc[df.성별 == 1]['성별']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3975    1
# 3976    1
# 3977    1
# 3978    1
# 3979    1
# Name: 성별, Length: 2022, dtype: int64

# %%
df.loc[df.성별 ==2]['성별']
# Out:
# 473     2
# 474     2
# 475     2
# 476     2
# 477     2
#        ..
# 3995    2
# 3996    2
# 3997    2
# 3998    2
# 3999    2
# Name: 성별, Length: 1978, dtype: int64

# %%
df['연령(1세)'] <= 20
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3995    False
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# Name: 연령(1세), Length: 4000, dtype: bool
#    직업  최종학력
# 0   6     8
# 1   6     8
# 2   6     8
# 3   6     8
# 4   6     8
#    직업  최종학력
# 0   6     8
# 1   6     8
# 2   6     8
# 3   6     8
# 4   6     8

# %%
df[df['연령(1세)'] <= 20][['직업', '최종학력']].head()
# Out:
#    직업  최종학력
# 0   6     8
# 1   6     8
# 2   6     8
# 3   6     8
# 4   6     8

# %%
df[(df['연령(1세)'] <= 20) & (df['성별'] == 1)][['직업', '최종학력']].head()
# Out:
#    직업  최종학력
# 0   6     8
# 1   6     8
# 2   6     8
# 3   6     8
# 4   6     8

# %%
df[(df['연령(1세)'] <= 35) | (df['성별'] == 1)].shape
# Out:
# (2737, 39)

# %%
df[~((df['연령(1세)'] <= 35) | (df['성별'] == 1))].shape
# Out:
# (1263, 39)

# %%
df['성별'].map({1:'남자', 2:'여자'})
# Out:
# 0       남자
# 1       남자
# 2       남자
# 3       남자
# 4       남자
#         ..
# 3995    여자
# 3996    여자
# 3997    여자
# 3998    여자
# 3999    여자
# Name: 성별, Length: 4000, dtype: object

# %%
df['성별'].map({1:'남자', 2:'여자'}).value_counts()
# Out:
# 남자    2022
# 여자    1978
# Name: 성별, dtype: int64

# %%
mapping = {1:' 남자 ', 2:' 여자 '}
df['성별'].map(mapping).value_counts()
# Out:
#  남자     2022
#  여자     1978
# Name: 성별, dtype: int64

# %%
df.head()
# Out:
#    성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0   1      14       1   6             6     8      3      2      99
# 1   1      14       1   6             6     8      1      2      99
# 2   1      14       1   6             6     8      2      2      99
# 3   1      14       1   6             8     8      1      2      99
# 4   1      14       1   6             9     8      1      2      99
#
#    평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  \
# 0             0.0  ...                          10.0
# 1            30.0  ...                          11.0
# 2            90.0  ...                          12.0
# 3             NaN  ...                           NaN
# 4             0.0  ...                          10.0
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  \
# 0                            13                           NaN
# 1                           NaN                           NaN
# 2                            14                           NaN
# 3                           NaN                           NaN
# 4                            11                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  PPL(간접광고) 평가 - 제품/브랜드 구매의향  구매
# 0                           NaN                           4   4
# 1                           NaN                           2   2
# 2                           NaN                           5   5
# 3                           NaN                           2   2
# 4                           NaN                           3   3
#
# [5 rows x 39 columns]

# %%
# apply(lamdda 함수 if 절에는 반드시 else가 있어야 함)
df['성별'] = df['성별'].apply(lambda x: '남자' if x == 1 else '여자')
df.head(2)
# Out:
#    성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0  남자      14       1   6             6     8      3      2      99
# 1  남자      14       1   6             6     8      1      2      99
#
#    평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  \
# 0             0.0  ...                          10.0
# 1            30.0  ...                          11.0
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  \
# 0                            13                           NaN
# 1                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  PPL(간접광고) 평가 - 제품/브랜드 구매의향  구매
# 0                           NaN                           4   4
# 1                           NaN                           2   2
#
# [2 rows x 39 columns]

# %%
df.성별.value_counts()
# Out:
# 남자    2022
# 여자    1978
# Name: 성별, dtype: int64

# %%
df.groupby('성별').count()
# Out:
#     연령(1세)  지역(권역)    직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 성별
# 남자    2022    2022  2022          2022  2022   2022   2022    2022
# 여자    1978    1978  1978          1978  1978   1978   1978    1978
#
#     평일 인터넷 이용시간(분)  토요일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  \
# 성별                                   ...
# 남자            1451             1451  ...                           632
# 여자            1152             1152  ...                          1098
#
#     TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  \
# 성별
# 남자                           348                           187
# 여자                           614                           323
#
#     TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  \
# 성별
# 남자                           113                            56
# 여자                           181                           119
#
#     TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  \
# 성별
# 남자                            32                            13
# 여자                            76                            42
#
#     TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  PPL(간접광고) 평가 - 제품/브랜드 구매의향    구매
# 성별
# 남자                             6                        2022  2022
# 여자                            16                        1978  1978
#
# [2 rows x 38 columns]

# %%
df.groupby('성별')['평일 인터넷 이용시간(분)'].mean()
# Out:
# 성별
# 남자    70.737422
# 여자    58.602431
# Name: 평일 인터넷 이용시간(분), dtype: float64

# %%
df['평일 인터넷 이용시간(분)'].groupby(df['성별']).mean()
# Out:
# 성별
# 남자    70.737422
# 여자    58.602431
# Name: 평일 인터넷 이용시간(분), dtype: float64

# %%
df.groupby('성별')['평일 인터넷 이용시간(분)'].mean().to_frame()
# Out:
#     평일 인터넷 이용시간(분)
# 성별
# 남자       70.737422
# 여자       58.602431

# %%
pd.DataFrame(df.groupby('성별')['평일 인터넷 이용시간(분)'].mean())
# Out:
#     평일 인터넷 이용시간(분)
# 성별
# 남자       70.737422
# 여자       58.602431

# %%
pd.DataFrame(df.groupby('성별')['평일 인터넷 이용시간(분)'].mean()).reset_index()
# Out:
#    성별  평일 인터넷 이용시간(분)
# 0  남자       70.737422
# 1  여자       58.602431

# %%
df.groupby(['성별', '직업'])['평일 인터넷 이용시간(분)',
                       '토요일 인터넷 이용시간(분)'].mean()
# Out:
#        평일 인터넷 이용시간(분)  토요일 인터넷 이용시간(분)
# 성별 직업
# 남자 1        73.904494        45.758427
#    2        80.313390        59.059829
#    3        65.957447        56.978723
#    4        51.940000        57.340000
#    6        77.427746        93.106936
#    7        66.153846        62.527473
# 여자 1        71.200000        52.800000
#    2        64.487069        48.711207
#    3        52.406417        51.470588
#    4        47.500000        42.500000
#    5        49.212544        36.689895
#    6        65.736301        81.866438
#    7        68.636364        69.318182

# %%
for group_id, sub_group in df.groupby('성별')['직업', '구매'] :
    group_id
    sub_group.shape
    sub_group.head(2)
# Out:
# '남자'
# (2022, 2)
#    직업  구매
# 0   6   4
# 1   6   2
# '여자'
# (1978, 2)
#      직업  구매
# 473   6   6
# 474   6   2

# %%
df.groupby('성별')['평일 인터넷 이용시간(분)'].mean().plot(kind ='bar')
# Out:
# <Axes: xlabel='성별'>

# %%
df.groupby('성별')['평일 인터넷 이용시간(분)',
                 '토요일 인터넷 이용시간(분)'].mean().plot(kind ='bar')
# Out:
# <Axes: xlabel='성별'>

# %%
df.groupby(['성별', '결혼 여부'])['평일 인터넷 이용시간(분)'].mean()
# Out:
# 성별  결혼 여부
# 남자  1        67.060766
#     2        74.806835
#     3        72.857143
# 여자  1        54.132219
#     2        64.836100
#     3        53.333333
# Name: 평일 인터넷 이용시간(분), dtype: float64

# %%
df.groupby(['성별', '결혼 여부'])['연령(1세)', '평일 인터넷 이용시간(분)'].mean()
# Out:
#              연령(1세)  평일 인터넷 이용시간(분)
# 성별 결혼 여부
# 남자 1      50.338160       67.060766
#    2      26.323155       74.806835
#    3      56.887097       72.857143
# 여자 1      48.864329       54.132219
#    2      23.400673       64.836100
#    3      59.083333       53.333333

# %%
df.groupby('성별')['구매'].value_counts()
# Out:
# 성별  구매
# 남자  3     803
#     2     475
#     4     430
#     5     151
#     1     142
#     6      21
# 여자  3     714
#     4     548
#     2     385
#     5     208
#     1      92
#     6      31
# Name: 구매, dtype: int64

# %%
df.groupby('성별')['구매'].value_counts().unstack() # 행 인덱스를 열 인덱스로 변경
# Out:
# 구매    1    2    3    4    5   6
# 성별
# 남자  142  475  803  430  151  21
# 여자   92  385  714  548  208  31

# %%
df.groupby('성별')['구매'].value_counts().unstack().plot.bar(rot='35', figsize=(15,3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-650eb395c987> in <cell line: 1>()
# ----> 1 df.groupby('성별')['구매'].value_counts().unstack().plot.bar(rot='35', figsize=(15,3))
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1157         other axis represents a measured value.
#    1158         """
# -> 1159         return self(kind="bar", x=x, y=y, **kwargs)
#    1160
#    1161     @Appender(
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     456
#     457         for ax in self.axes:
# --> 458             self._post_plot_logic_common(ax, self.data)
#     459             self._post_plot_logic(ax, self.data)
#     460
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic_common(self, ax, data)
#     653         """Common post process for each axes"""
#     654         if self.orientation == "vertical" or self.orientation is None:
# --> 655             self._apply_axis_properties(ax.xaxis, rot=self.rot, fontsize=self.fontsize)
#     656             self._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     657
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _apply_axis_properties(self, axis, rot, fontsize)
#     745             for label in labels:
#     746                 if rot is not None:
# --> 747                     label.set_rotation(rot)
#     748                 if fontsize is not None:
#     749                     label.set_fontsize(fontsize)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py in set_rotation(self, s)
#    1232             self._rotation = 90.
#    1233         else:
# -> 1234             raise ValueError("rotation must be 'vertical', 'horizontal' or "
#    1235                              f"a number, not {s}")
#    1236         self.stale = True
#
# ValueError: rotation must be 'vertical', 'horizontal' or a number, not 35

# %%
import seaborn as sns
ax = sns.heatmap(df.groupby('성별')['구매'].value_counts().unstack(),
                 fmt='d', annot=True)

# %%
df.pivot_table(values=['최종학력'], index=['성별'], columns=['구매'], aggfunc='count')
# Out:
#    최종학력
# 구매    1    2    3    4    5   6
# 성별
# 남자  142  475  803  430  151  21
# 여자   92  385  714  548  208  31

# %%
pd.crosstab(df['성별'], df['구매'])
# Out:
# 구매    1    2    3    4    5   6
# 성별
# 남자  142  475  803  430  151  21
# 여자   92  385  714  548  208  31

# %%
tf = df.pivot_table(values=['최종학력'], index=['성별'], columns=['구매'], aggfunc='count')
tf.loc['합계_열'] = tf.sum()
tf['합계_행'] = tf.sum(axis=1)
tf
# Out:
#      최종학력                           합계_행
# 구매      1    2     3    4    5   6
# 성별
# 남자    142  475   803  430  151  21  2022
# 여자     92  385   714  548  208  31  1978
# 합계_열  234  860  1517  978  359  52  4000

# %%
df.groupby('성별')['구매'].describe()
# Out:
#      count      mean      std  min  25%  50%  75%  max
# 성별
# 남자  2022.0  3.017804  1.05873  1.0  2.0  3.0  4.0  6.0
# 여자  1978.0  3.246714  1.07663  1.0  3.0  3.0  4.0  6.0

# %%
df.groupby('성별')['구매'].describe().reset_index()
# Out:
#    성별   count      mean      std  min  25%  50%  75%  max
# 0  남자  2022.0  3.017804  1.05873  1.0  2.0  3.0  4.0  6.0
# 1  여자  1978.0  3.246714  1.07663  1.0  3.0  3.0  4.0  6.0

# %%
df.groupby('성별')['구매'].describe().reset_index().set_index('성별')
# Out:
#      count      mean      std  min  25%  50%  75%  max
# 성별
# 남자  2022.0  3.017804  1.05873  1.0  2.0  3.0  4.0  6.0
# 여자  1978.0  3.246714  1.07663  1.0  3.0  3.0  4.0  6.0

# %%
for (method, group) in df.groupby('성별'):
    print("{0:30s} shape={1}".format(method, group.shape))
    group.head(2)
    group['구매'].mean()
# Out:
# 남자                             shape=(2022, 39)
#    성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 0  남자      14       1   6             6     8      3      2      99
# 1  남자      14       1   6             6     8      1      2      99
#
#    평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  \
# 0             0.0  ...                          10.0
# 1            30.0  ...                          11.0
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  \
# 0                            13                           NaN
# 1                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  PPL(간접광고) 평가 - 제품/브랜드 구매의향  구매
# 0                           NaN                           4   4
# 1                           NaN                           2   2
#
# [2 rows x 39 columns]
# 3.0178041543026706
# 여자                             shape=(1978, 39)
#      성별  연령(1세)  지역(권역)  직업  가구 월평균 소득(1)  최종학력  주거 형태  결혼 여부  자녀 총 수  \
# 473  여자      14       1   6             5     8      1      2      99
# 474  여자      14       1   6             6     8      1      2      99
#
#      평일 인터넷 이용시간(분)  ...  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.2  \
# 473            60.0  ...                           NaN
# 474            30.0  ...                           NaN
#
#      TV 시청 시 즐겨 보는 국내 드라마 장르-내용.3  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.4  \
# 473                           NaN                           NaN
# 474                           NaN                           NaN
#
#      TV 시청 시 즐겨 보는 국내 드라마 장르-내용.5  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.6  \
# 473                           NaN                           NaN
# 474                           NaN                           NaN
#
#      TV 시청 시 즐겨 보는 국내 드라마 장르-내용.7  TV 시청 시 즐겨 보는 국내 드라마 장르-내용.8  \
# 473                           NaN                           NaN
# 474                           NaN                           NaN
#
#      TV 시청 시 즐겨 보는 국내 드라마 장르-내용.9  PPL(간접광고) 평가 - 제품/브랜드 구매의향  구매
# 473                           NaN                           6   6
# 474                           NaN                           2   2
#
# [2 rows x 39 columns]
# 3.2467138523761374
