# %% [markdown]
# ### Python 에서 HTTP 통신 등으로 데이터를 주고 받을 때 JSON 형태로 주고 받는 경우
# - JSON을 Dictionary 형태로 변환하는 방법
# - Dictionary 형태를 JSON 으로 변환하는 방법
# - json 모듈을 사용

# %% [markdown]
# > ### **JSON파일은 사전형의 'str' 형태로 JSON to Dictionary로 변경하려면 - json.loads()**

# %%
json_example = '''
{
    "olivia": {"gender": "female", "age": 25, "hobby": ["reading", "music"]},
    "Tyler": {"gender": "male", "age": 28, "hobby": ["development", "painting"]}
    }
'''

# %%
print("JSON Type : ", type(json_example))
print("JSON : ", json_example)
# Out:
# JSON Type :  <class 'str'>
# JSON :
# {
#     "olivia": {"gender": "female", "age": 25, "hobby": ["reading", "music"]},
#     "Tyler": {"gender": "male", "age": 28, "hobby": ["development", "painting"]}
#     }

# %%
import json
dict_example = json.loads(json_example) # Convert json to dict
print("JSON Type : ", type(dict_example))
print("JSON : ", dict_example)
# Out:
# JSON Type :  <class 'dict'>
# JSON :  {'olivia': {'gender': 'female', 'age': 25, 'hobby': ['reading', 'music']}, 'Tyler': {'gender': 'male', 'age': 28, 'hobby': ['development', 'painting']}}

# %% [markdown]
# ## **1. Convert json to dataframe**

# %%
import pandas as pd

# %%
df = pd.read_json(json_example)
df
# Out:
#                   olivia                    Tyler
# gender            female                     male
# age                   25                       28
# hobby   [reading, music]  [development, painting]

# %% [markdown]
# ## **2. convert dict to dataframe**

# %%
df = pd.DataFrame.from_dict(dict_example)
df
# Out:
#                   olivia                    Tyler
# gender            female                     male
# age                   25                       28
# hobby   [reading, music]  [development, painting]

# %%
df = pd.DataFrame(dict_example)
df
# Out:
#                   olivia                    Tyler
# gender            female                     male
# age                   25                       28
# hobby   [reading, music]  [development, painting]

# %% [markdown]
# ## **3. convert dataframe to json**

# %%
json_output = df.to_json()
print(json_output)
print(type(json_output))
# Out:
# {"olivia":{"gender":"female","age":25,"hobby":["reading","music"]},"Tyler":{"gender":"male","age":28,"hobby":["development","painting"]}}
# <class 'str'>

# %%
json.loads(json_output)
# Out:
# {'olivia': {'gender': 'female', 'age': 25, 'hobby': ['reading', 'music']},
#  'Tyler': {'gender': 'male', 'age': 28, 'hobby': ['development', 'painting']}}

# %%
print(type(json.loads(json_output)))
# Out:
# <class 'dict'>

# %%
# Convert DataFrame to JSON
json_output = df.to_json(orient="records")  # 행 단위로 만들기
print(json_output)
print(type(json_output))
# Out:
# [{"olivia":"female","Tyler":"male"},{"olivia":25,"Tyler":28},{"olivia":["reading","music"],"Tyler":["development","painting"]}]
# <class 'str'>

# %%
# Out:
# <class 'str'>

# %% [markdown]
# ## **4. convert dataframe to dict**

# %%
df
# Out:
#                   olivia                    Tyler
# gender            female                     male
# age                   25                       28
# hobby   [reading, music]  [development, painting]

# %%
# Access Olivia's gender
olivia_gender = df["olivia"]["gender"]
olivia_gender
# Out:
# 'female'

# %%
# Access Tyler's age
tyler_age = df["Tyler"]["age"]
tyler_age
# Out:
# 28

# %%
# Access Tyler's hobbies
tyler_hobbies = df["Tyler"]["hobby"]
tyler_hobbies
# Out:
# ['development', 'painting']

# %%
for index, row in df.iterrows():
    print(f'index :---> {index}')
    print(f'row :---> {row}')
    print('*'*100)
# Out:
# index :---> gender
# row :---> olivia    female
# Tyler       male
# Name: gender, dtype: object
# ****************************************************************************************************
# index :---> age
# row :---> olivia    25
# Tyler     28
# Name: age, dtype: object
# ****************************************************************************************************
# index :---> hobby
# row :---> olivia           [reading, music]
# Tyler     [development, painting]
# Name: hobby, dtype: object
# ****************************************************************************************************

# %%
df.T
# Out:
#         gender age                    hobby
# olivia  female  25         [reading, music]
# Tyler     male  28  [development, painting]

# %%
# Transpose the data frame and convert it to a dictionary
data_dict = df.T.to_dict(orient='index')
print(data_dict)
# Out:
# {'olivia': {'gender': 'female', 'age': 25, 'hobby': ['reading', 'music']}, 'Tyler': {'gender': 'male', 'age': 28, 'hobby': ['development', 'painting']}}

# %%
df.to_dict(orient='dict')
# Out:
# {'olivia': {'gender': 'female', 'age': 25, 'hobby': ['reading', 'music']},
#  'Tyler': {'gender': 'male', 'age': 28, 'hobby': ['development', 'painting']}}

# %% [markdown]
# ### **추가 학습**

# %%
pip install faker
# Out:
# Collecting faker
#   Downloading Faker-19.6.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-19.6.2

# %%
from faker import Faker
fake = Faker('tr_TR')

# %%
data = {
    'name': [fake.name() for _ in range(100)],
    'phone #': [fake.phone_number() for _ in range(100)],
    'city': [fake.city() for _ in range(100)]
}

df = pd.DataFrame(data)
df
# Out:
#                             name                phone #               city
# 0              Prof. Kayıt Akçay  +90(719)611-6609x8341      New Solmabury
# 1   Şerman Vecide Tarhan Alemdar      +90 (049) 8800985       North Gökçil
# 2       Şeyda Azade Mansız Aslan        +90(525)3962482         Mansızland
# 3                    Mishat Aksu        +90(755)7695510  Lake Sidarchester
# 4                   Acarkan Akça              116 9 636         Duranville
# ..                           ...                    ...                ...
# 95     Teber İlteriş Çamurcuoğlu          0359-472 2094        Safuramouth
# 96        Aynımah Sanavber Bilir        +90(625)7218043  South Nurbanuport
# 97                   Akver Arsoy      +90 (126) 1773131        South Nafii
# 98      Öğr. Özlem Akdeniz Şener         0339 954 98 79         Gülchester
# 99          Mükramin Fehim Ertaş          (823)637 0595   South Kelâmiview
#
# [100 rows x 3 columns]

# %% [markdown]
# - df.to_json(orient="records") 메서드에서 orient 매개변수는 DataFrame이 JSON 문자열로 변환되어야 하는 형식을 지정
# - orient 매개변수의 "records" 값은 DataFrame이 사전 목록으로 변환을 나타냄
# - 각 사전은 DataFrame의 레코드(행)를 표시

# %%
df
# Out:
#                             name                phone #               city
# 0              Prof. Kayıt Akçay  +90(719)611-6609x8341      New Solmabury
# 1   Şerman Vecide Tarhan Alemdar      +90 (049) 8800985       North Gökçil
# 2       Şeyda Azade Mansız Aslan        +90(525)3962482         Mansızland
# 3                    Mishat Aksu        +90(755)7695510  Lake Sidarchester
# 4                   Acarkan Akça              116 9 636         Duranville
# ..                           ...                    ...                ...
# 95     Teber İlteriş Çamurcuoğlu          0359-472 2094        Safuramouth
# 96        Aynımah Sanavber Bilir        +90(625)7218043  South Nurbanuport
# 97                   Akver Arsoy      +90 (126) 1773131        South Nafii
# 98      Öğr. Özlem Akdeniz Şener         0339 954 98 79         Gülchester
# 99          Mükramin Fehim Ertaş          (823)637 0595   South Kelâmiview
#
# [100 rows x 3 columns]

# %%
df.to_dict(orient='index')
# Out:
# {0: {'name': 'Prof. Kayıt Akçay',
#   'phone #': '+90(719)611-6609x8341',
#   'city': 'New Solmabury'},
#  1: {'name': 'Şerman Vecide Tarhan Alemdar',
#   'phone #': '+90 (049) 8800985',
#   'city': 'North Gökçil'},
#  2: {'name': 'Şeyda Azade Mansız Aslan',
#   'phone #': '+90(525)3962482',
#   'city': 'Mansızland'},
#  3: {'name': 'Mishat Aksu',
#   'phone #': '+90(755)7695510',
#   'city': 'Lake Sidarchester'},
#  4: {'name': 'Acarkan Akça', 'phone #': '116 9 636', 'city': 'Duranville'},
#  5: {'name': 'Mücellib Ertaş',
#   'phone #': '(410)155 3853',
#   'city': 'North Hanbikenfort'},
#  6: {'name': 'Bican Ertan Duran Türk',
#   'phone #': '0374 427 31 06',
#   'city': 'South Şamihaton'},
#  7: {'name': 'Aytek İhsanoğlu',
#   'phone #': '(894)425 7720',
#   'city': 'Türkmenville'},
#  8: {'name': 'Tanyolaç Arslan',
#   'phone #': '+90(802)3127507',
#   'city': 'Port Vezatside'},
#  9: {'name': 'Çev. Velitdin Karadeniz',
#   'phone #': '09890143792',
#   'city': 'West Nurullah'},
#  10: {'name': 'Nazende Hayrioğlu',
#   'phone #': '+90(299)262-8758x457',
#   'city': 'Gülenfurt'},
#  11: {'name': 'Ayşeana Yıldırım',
#   'phone #': '01461025368',
#   'city': 'East Zennunville'},
#  12: {'name': 'Feden Aysevim Yılmaz',
#   'phone #': '+90(903)817-5484x933',
#   'city': 'Lake Ufukayton'},
#  13: {'name': 'Aşhan Faize Durmuş',
#   'phone #': '+90(417)653-7319x240',
#   'city': 'South Tunguç'},
#  14: {'name': 'Nihai Aslan',
#   'phone #': '+90(336)610-0490x806',
#   'city': 'North Nihai'},
#  15: {'name': 'Onuker Yaman',
#   'phone #': '+90(911)5591054',
#   'city': 'West Ferihantown'},
#  16: {'name': 'İlmafer Çetin',
#   'phone #': '+90 (835) 7562409',
#   'city': 'Lake Gönenberg'},
#  17: {'name': 'Ergül Cedide Şener',
#   'phone #': '(489)741 7329',
#   'city': 'Ergülside'},
#  18: {'name': 'Çerçi Çağveren Ülker Hayrioğlu',
#   'phone #': '04885881225',
#   'city': 'Yertanhaven'},
#  19: {'name': 'Doç. Ayşenur Semrin Türk Aksu',
#   'phone #': '+90(034)2867754',
#   'city': 'North Heva'},
#  20: {'name': 'Dr. Şahinder İmge Arsoy',
#   'phone #': '+90 (815) 2449799',
#   'city': 'Akçabury'},
#  21: {'name': 'Ilgı Bilir',
#   'phone #': '196 7 082',
#   'city': 'East Safuramouth'},
#  22: {'name': 'Öğr. Berki Yaman', 'phone #': '334 5 150', 'city': 'New Feyha'},
#  23: {'name': 'Hunalp Dumanlı',
#   'phone #': '+90(917)928-9616x9442',
#   'city': 'Port Barsen'},
#  24: {'name': 'Dincer Yıldırım',
#   'phone #': '+90(370)0582788',
#   'city': 'Kaderville'},
#  25: {'name': 'Okt. Işıkay Ergül',
#   'phone #': '+90 (571) 3851785',
#   'city': 'East Ayasun'},
#  26: {'name': 'Gencaslan Ünübol Demirel Bilgin',
#   'phone #': '(768)163 3676',
#   'city': 'Alemdarbury'},
#  27: {'name': 'Timurtaş Ertaş',
#   'phone #': '+90 (373) 4002562',
#   'city': 'Alcanfurt'},
#  28: {'name': 'Öğr. Laze Melikkan Bilge Mansız',
#   'phone #': '253 6 507',
#   'city': 'Lake Ildız'},
#  29: {'name': 'Prof. Özbilge Hadrey Arsoy',
#   'phone #': '+90(515)9157030',
#   'city': 'East Aruland'},
#  30: {'name': 'Zülfüye Gül',
#   'phone #': '01094462365',
#   'city': 'West Yaşattin'},
#  31: {'name': 'Dr. Eriş Mücevher İnönü',
#   'phone #': '743 3 550',
#   'city': 'East Çakarhaven'},
#  32: {'name': 'Çevregül Demirel',
#   'phone #': '891 2 195',
#   'city': 'North Muvaffaktown'},
#  33: {'name': 'Aru Bilge',
#   'phone #': '+90(460)726-8167x296',
#   'city': 'Yılmazfurt'},
#  34: {'name': 'Yosma Akmaral Akça',
#   'phone #': '(667)798 2676',
#   'city': 'Şensoyville'},
#  35: {'name': 'Okt. Niğmet Şensoy Duran',
#   'phone #': '09937462765',
#   'city': 'East Doğuhan'},
#  36: {'name': 'Okt. Galip Öcalan',
#   'phone #': '+90(241)239-9032x2602',
#   'city': 'Şafakborough'},
#  37: {'name': 'Neval Akgündüz',
#   'phone #': '+90 (013) 4093665',
#   'city': 'Eşimview'},
#  38: {'name': 'Uğurkan Demirel',
#   'phone #': '+90(304)520-3680x040',
#   'city': 'Erdoğanburgh'},
#  39: {'name': 'Öğr. İzel Arsoy Yorulmaz',
#   'phone #': '+90(742)6426532',
#   'city': 'North Emişbury'},
#  40: {'name': 'Erdibay Eraslan',
#   'phone #': '+90(904)3525258',
#   'city': 'East Erksoyburgh'},
#  41: {'name': 'Ömriye Arsoy',
#   'phone #': '(643)511 0454',
#   'city': 'Hayrioğluview'},
#  42: {'name': 'Necmettin Akça',
#   'phone #': '0293-602 8798',
#   'city': 'South Uçan'},
#  43: {'name': 'Bayan Şelâle Dürrüşehvar Yüksel',
#   'phone #': '616 8 756',
#   'city': 'Yükselshire'},
#  44: {'name': 'Öğr. Gülgen Cevale Çamurcuoğlu',
#   'phone #': '(695)347 5861',
#   'city': 'North Kutgün'},
#  45: {'name': 'Sezal Sücaettin Manço Tevetoğlu',
#   'phone #': '+90(160)163-4692x403',
#   'city': 'New Azizeberg'},
#  46: {'name': 'Akgüneş Demir',
#   'phone #': '0824 457 91 98',
#   'city': 'Mançomouth'},
#  47: {'name': 'Toköz Huzuri Manço',
#   'phone #': '+90 (740) 1577953',
#   'city': 'West Gülağa'},
#  48: {'name': 'Rahmet Tutkun Ertaş',
#   'phone #': '+90(077)382-7591x5340',
#   'city': 'South Fadılaville'},
#  49: {'name': 'Yayak Bekbay Çetin',
#   'phone #': '0777-357 5294',
#   'city': 'North Çağdan'},
#  50: {'name': 'Atiyye Ümray Yılmaz Gül',
#   'phone #': '+90 (786) 0463110',
#   'city': 'Tatuhaven'},
#  51: {'name': 'Av. Aran Arcan Tarhan',
#   'phone #': '0653 836 98 59',
#   'city': 'New Selmin'},
#  52: {'name': 'Büreyre Şahdiye Alemdar Yıldırım',
#   'phone #': '0666-669 5701',
#   'city': 'Lake Nurcan'},
#  53: {'name': 'Sağıt Yilmaz Sezgin Demirel',
#   'phone #': '499 8 548',
#   'city': 'Sezginshire'},
#  54: {'name': 'Doğanalp Arslan',
#   'phone #': '+90 (608) 1951254',
#   'city': 'West Güllühan'},
#  55: {'name': 'Dr. Toktuğ Bilgin',
#   'phone #': '+90(745)572-4190x7228',
#   'city': 'Akçaburgh'},
#  56: {'name': 'Öğr. Tule Gülter Mansız',
#   'phone #': '+90(926)183-8951x7324',
#   'city': 'Akarmouth'},
#  57: {'name': 'Sevdi Bilgütay Bilge Hançer',
#   'phone #': '08810435918',
#   'city': 'South Günver'},
#  58: {'name': 'Öğr. Eral Durdu',
#   'phone #': '(750)667 6433',
#   'city': 'South İhsan'},
#  59: {'name': 'Atnan Öcalan',
#   'phone #': '+90(616)6190263',
#   'city': 'South Arpağside'},
#  60: {'name': 'Sargın Özsözlü Türk Zorlu',
#   'phone #': '(462)848 9923',
#   'city': 'Akbaşberg'},
#  61: {'name': 'Vecide Zilfa Güçlü Zengin',
#   'phone #': '+90(870)592-2031x8939',
#   'city': 'West Nuyanport'},
#  62: {'name': 'Nurkan Soylu',
#   'phone #': '+90 (145) 8972869',
#   'city': 'New Bayruhanchester'},
#  63: {'name': 'Kâmil Günser Erdoğan Akçay',
#   'phone #': '0138 344 22 35',
#   'city': 'New Suphi'},
#  64: {'name': 'Tangül Merim Sakarya Şafak',
#   'phone #': '(461)934 9493',
#   'city': 'İhsanoğlufurt'},
#  65: {'name': 'Öğr. Sümerya Anka Öcalan',
#   'phone #': '0132-306 9629',
#   'city': 'West Türknur'},
#  66: {'name': 'Gökperi Şama',
#   'phone #': '+90(515)4149994',
#   'city': 'West Ruhidehaven'},
#  67: {'name': 'Mesude Hançer Soylu',
#   'phone #': '+90(959)089-6844x699',
#   'city': 'Akarfurt'},
#  68: {'name': 'Çev. Hacile Meveddet Demir',
#   'phone #': '+90(319)049-5846x887',
#   'city': 'New Gürsal'},
#  69: {'name': 'Öğr. Sezal Yüksel',
#   'phone #': '0330-161 5244',
#   'city': 'Ertaşchester'},
#  70: {'name': 'Yrd. Doç. Meşhur Kader Akar',
#   'phone #': '776 5 917',
#   'city': 'West Gülkadın'},
#  71: {'name': 'Abdulkadir Sezer', 'phone #': '926 2 874', 'city': 'Türkshire'},
#  72: {'name': 'Prof. Şevket Doğanalp Aksu',
#   'phone #': '+90(084)017-4451x9623',
#   'city': 'Lake Tayganville'},
#  73: {'name': 'Hürüyet Hilayda Demir',
#   'phone #': '+90(828)128-7542x3711',
#   'city': 'North Adasalton'},
#  74: {'name': 'Bay Sançar Teber Seven',
#   'phone #': '+90(771)8523857',
#   'city': 'Şensoyshire'},
#  75: {'name': 'Ümmühan Çorlu Durdu',
#   'phone #': '0074-989 6382',
#   'city': 'Musafetmouth'},
#  76: {'name': 'Fatinur Akça',
#   'phone #': '(960)070 1969',
#   'city': 'Port Şendoğanport'},
#  77: {'name': 'Nurkan Çamurcuoğlu',
#   'phone #': '0362-175 0719',
#   'city': 'West Ertuncaymouth'},
#  78: {'name': 'Prof. Tunçkılıç Akgündüz',
#   'phone #': '814 0 298',
#   'city': 'Sevenside'},
#  79: {'name': 'Nazıdil Elvan Yılmaz Arsoy',
#   'phone #': '0742 066 30 04',
#   'city': 'New Mahnaz'},
#  80: {'name': 'Dr. Hüsnühâl Manço Sakarya',
#   'phone #': '+90(171)328-5276x9141',
#   'city': 'Sakaryamouth'},
#  81: {'name': 'Neval Sefer Tevetoğlu Akçay',
#   'phone #': '019 7 285',
#   'city': 'Hançerport'},
#  82: {'name': 'Cabir Gündüzalp Güçlü',
#   'phone #': '(810)679 0316',
#   'city': 'North Muhyettin'},
#  83: {'name': 'Yrd. Doç. Feden Şama Dumanlı',
#   'phone #': '+90(427)6932847',
#   'city': 'Bilginville'},
#  84: {'name': 'Benol Yılmaz', 'phone #': '485 9 229', 'city': 'Ergülport'},
#  85: {'name': 'Gülbani Ertaş',
#   'phone #': '+90(367)099-9663x6662',
#   'city': 'New Akatay'},
#  86: {'name': 'Algış Temime Manço Erdoğan',
#   'phone #': '+90(589)993-5914x482',
#   'city': 'Divanhaven'},
#  87: {'name': 'Öğr. İçimbike Şensoy Hançer',
#   'phone #': '254 6 383',
#   'city': 'Port Yuntfurt'},
#  88: {'name': 'Nevsale Mehdiye Akar',
#   'phone #': '904 9 926',
#   'city': 'North Tezcanshire'},
#  89: {'name': 'Öğr. Altınbike Sefer Çetin',
#   'phone #': '+90(523)899-7328x226',
#   'city': 'East Öncel'},
#  90: {'name': 'Doç. Demiryürek Mutluhan Yorulmaz',
#   'phone #': '08212986813',
#   'city': 'Nesipland'},
#  91: {'name': 'Prof. Gülkadın Manço Demirel',
#   'phone #': '(046)482 7695',
#   'city': 'Lake Razıville'},
#  92: {'name': 'Hasbek Erkinel Akar Yüksel',
#   'phone #': '0316-015 8690',
#   'city': 'Niyazishire'},
#  93: {'name': 'Arş. Gör. Nevgin Laze Eraslan',
#   'phone #': '07422827157',
#   'city': 'Lake Taşkanview'},
#  94: {'name': 'Canfeza Aysevim Demirel',
#   'phone #': '+90(183)424-4316x213',
#   'city': 'Lake Oganer'},
#  95: {'name': 'Teber İlteriş Çamurcuoğlu',
#   'phone #': '0359-472 2094',
#   'city': 'Safuramouth'},
#  96: {'name': 'Aynımah Sanavber Bilir',
#   'phone #': '+90(625)7218043',
#   'city': 'South Nurbanuport'},
#  97: {'name': 'Akver Arsoy',
#   'phone #': '+90 (126) 1773131',
#   'city': 'South Nafii'},
#  98: {'name': 'Öğr. Özlem Akdeniz Şener',
#   'phone #': '0339 954 98 79',
#   'city': 'Gülchester'},
#  99: {'name': 'Mükramin Fehim Ertaş',
#   'phone #': '(823)637 0595',
#   'city': 'South Kelâmiview'}}

# %%
df.to_json(orient="records")
# Out:
# '[{"name":"Okt. Ma\\u015fide Elamiye Korut\\u00fcrk \\u015eener","phone #":"0469-672 0965","city":"Andi\\u00e7side"},{"name":"Co\\u015fkun Arpa\\u011f Seven K\\u0131sak\\u00fcrek","phone #":"06848960764","city":"Port Denkelfurt"},{"name":"\\u00d6\\u011fr. Say\\u0131n Akmaner Korut\\u00fcrk","phone #":"068 3 673","city":"Aliseydiland"},{"name":"Yoru\\u00e7 Y\\u00fcksel","phone #":"+90(586)782-0539x5873","city":"Dilfezaborough"},{"name":"Ya\\u011f\\u0131zkurt Mansurali Bilir Mans\\u0131z","phone #":"0344-228 8857","city":"G\\u00fclkad\\u0131nhaven"},{"name":"Beriye Abiye \\u00c7orlu","phone #":"+90 (696) 7467060","city":"Sakaryaland"},{"name":"Okt. \\u015ead\\u0131man Alemdar \\u015eensoy","phone #":"0272-715 5645","city":"Port Geray"},{"name":"Uz. Asiman Nurhayet Durdu","phone #":"0459 050 02 07","city":"West Atilhan"},{"name":"Koray \\u00c7amurcuo\\u011flu","phone #":"+90(386)701-9149x5232","city":"Bilgestad"},{"name":"Sejda \\u00c7amurcuo\\u011flu","phone #":"+90(572)680-9091x3880","city":"Y\\u00fckselberg"},{"name":"Fidaye Alsoy Sakarya","phone #":"04651448371","city":"New \\u00c7apkan"},{"name":"Yurdanur Yorulmaz","phone #":"0321 592 09 52","city":"\\u015eensoyville"},{"name":"Zahfer Sakarya Bilge","phone #":"+90(424)803-0995x663","city":"Sevenbury"},{"name":"Erenalp Teveto\\u011flu","phone #":"(652)317 8204","city":"West Elvanside"},{"name":"Arkut Ak\\u00f6z Seven Aksu","phone #":"+90 (932) 5193780","city":"West Aliseydiberg"},{"name":"Yosma Sezer","phone #":"+90(769)383-6680x6926","city":"Sarpk\\u0131nberg"},{"name":"Hurican Mecide Akg\\u00fcnd\\u00fcz G\\u00fclen","phone #":"531 0 029","city":"Aliseydiville"},{"name":"Erse\\u00e7 Bilgin","phone #":"243 0 946","city":"Soydanerton"},{"name":"D\\u00fcrr\\u00fc\\u015fehvar \\u015eerman Ak\\u00e7ay","phone #":"05278173319","city":"West G\\u00fcl\\u00fcs"},{"name":"Berrin Nasiba \\u015eener \\u015eensoy","phone #":"03689439725","city":"Port Feratmouth"},{"name":"\\u00d6ver Hatem Erg\\u00fcl","phone #":"05926946888","city":"\\u015eilanland"},{"name":"Jankat Zorlu","phone #":"+90(202)861-6357x295","city":"Rahiyeshire"},{"name":"Tanyu Nuriyet Alemdar Aslan","phone #":"206 5 932","city":"Lake \\u0130smetfort"},{"name":"Bay Hanedan \\u00d6calan","phone #":"+90 (473) 6828512","city":"Port V\\u00e2l\\u00e2fort"},{"name":"Kader Ak\\u00e7ay","phone #":"04381288428","city":"Teveto\\u011flufurt"},{"name":"Do\\u00e7. \\u00d6zbay Duran","phone #":"277 6 128","city":"\\u00dclkershire"},{"name":"Sevim \\u015eensoy","phone #":"04930872009","city":"Han\\u00e7erstad"},{"name":"\\u0130diris K\\u0131sak\\u00fcrek","phone #":"+90(042)8316998","city":"South Abdulbekirbury"},{"name":"Ergener Demir","phone #":"0467 836 50 05","city":"West Tolonbayborough"},{"name":"Ferahdiba Permun G\\u00fc\\u00e7l\\u00fc","phone #":"+90(775)166-8187x906","city":"Bilirmouth"},{"name":"Muvaffak G\\u00fcrelcem Eraslan","phone #":"+90(349)213-1077x3145","city":"Nazlimside"},{"name":"Prof. Hatin Akar Erg\\u00fcl","phone #":"03674149114","city":"Dumanl\\u0131haven"},{"name":"Rana Akdeniz","phone #":"04119153447","city":"Port G\\u00f6ken"},{"name":"Av. Tayyip G\\u00f6nen Bilge","phone #":"0535 928 95 18","city":"East Sayrakfort"},{"name":"Oru\\u00e7 Soylu","phone #":"(897)179 7842","city":"Port Oganer"},{"name":"G\\u00fcnver Aygutalp F\\u0131rat","phone #":"(401)403 9730","city":"\\u00c7amurcuo\\u011flufurt"},{"name":"Ar\\u015f. G\\u00f6r. Asu \\u015eafak Y\\u00fcksel","phone #":"(224)754 1086","city":"New Zennunfurt"},{"name":"Do\\u00e7. Nurkan Tamayd\\u0131n Eraslan","phone #":"+90(204)443-1705x9570","city":"Akdenizchester"},{"name":"G\\u00fclfeza Kutg\\u00fcn Akar","phone #":"+90(849)782-4027x194","city":"Raz\\u0131chester"},{"name":"Uz. Sudi \\u00d6calan","phone #":"(687)497 2067","city":"Arslanmouth"},{"name":"\\u00d6\\u011fr. Hindal Karadeniz","phone #":"+90(733)395-4208x120","city":"\\u00dclk\\u00fcde\\u015fberg"},{"name":"Bay H\\u00fcsmen \\u00c2dem \\u00c7etin","phone #":"+90(016)751-5614x992","city":"\\u00c7amokb ...

# %% [markdown]
# > ### **Dictionary to JSON - json.dumps()**

# %%
import json

dict_example = {
  "olivia" : {
    "gender": "female",
    "age" : 25,
    "hobby" : ["reading", "music"]
  },
  "Tyler" : {
    "gender": "male",
    "age" : 28,
    "hobby" : ["development", "painting"]
  }
}

json_example = json.dumps(dict_example) # Convert dict to json

# %%
print("Dictionary Type : ", type(dict_example))
print("Dictionary : ", dict_example)
# Out:
# Dictionary Type :  <class 'dict'>
# Dictionary :  {'olivia': {'gender': 'female', 'age': 25, 'hobby': ['reading', 'music']}, 'Tyler': {'gender': 'male', 'age': 28, 'hobby': ['development', 'painting']}}

# %%
print("JSON Type : ", type(json_example))
print("JSON : ", json_example)
# Out:
# JSON Type :  <class 'str'>
# JSON :  {"olivia": {"gender": "female", "age": 25, "hobby": ["reading", "music"]}, "Tyler": {"gender": "male", "age": 28, "hobby": ["development", "painting"]}}
